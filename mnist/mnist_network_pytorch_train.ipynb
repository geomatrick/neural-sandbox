# %%
import mnist_loader
import mnist_network_pytorch

training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/pickle.py:1590: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   stack[-1] = func(*args)

# %%
net = mnist_network_pytorch.Network([784, 30, 10])
net.train_network(training_data, 30, 10, 3.0, test_data=test_data)
# Out:
# Epoch 0: 9246 / 10000
# Epoch 1: 9383 / 10000
# Epoch 2: 9428 / 10000
# Epoch 3: 9485 / 10000
# Epoch 4: 9518 / 10000
# Epoch 5: 9524 / 10000
# Epoch 6: 9556 / 10000
# Epoch 7: 9542 / 10000
# Epoch 8: 9567 / 10000
# Epoch 9: 9567 / 10000
# Epoch 10: 9555 / 10000
# Epoch 11: 9561 / 10000
# Epoch 12: 9578 / 10000
# Epoch 13: 9578 / 10000
# Epoch 14: 9600 / 10000
# Epoch 15: 9579 / 10000
# Epoch 16: 9590 / 10000
# Epoch 17: 9605 / 10000
# Epoch 18: 9599 / 10000
# Epoch 19: 9589 / 10000
# Epoch 20: 9604 / 10000
# Epoch 21: 9610 / 10000
# Epoch 22: 9612 / 10000
# Epoch 23: 9607 / 10000
# Epoch 24: 9608 / 10000
# Epoch 25: 9596 / 10000
# Epoch 26: 9602 / 10000
# Epoch 27: 9611 / 10000
# Epoch 28: 9597 / 10000
# Epoch 29: 9594 / 10000

# %%
import mnist_loader
import mnist_network3_pytorch

training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/pickle.py:1590: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   stack[-1] = func(*args)

# %%
net = mnist_network3_pytorch.Network([
                mnist_network3_pytorch.ConvPoolLayer(1, 20, 5, 2),
                mnist_network3_pytorch.FullyConnectedLayer(20*12*12, 100, dropout_rate=0.5),
                mnist_network3_pytorch.SoftmaxLayer(100, 10)
            ])
net.train_network(training_data, 10, 10, 0.1, test_data=test_data)
# Out:
# Epoch 0: 1032 / 10000
# Epoch 1: 892 / 10000
# Epoch 2: 974 / 10000
# Epoch 3: 958 / 10000
# Epoch 4: 1135 / 10000
# Epoch 5: 958 / 10000
# Epoch 6: 892 / 10000
# Epoch 7: 1135 / 10000
# Epoch 8: 1010 / 10000
# Epoch 9: 1032 / 10000
# Epoch 10: 1032 / 10000
# Epoch 11: 982 / 10000
# Epoch 12: 1028 / 10000
# Epoch 13: 1009 / 10000
# Epoch 14: 1028 / 10000
# Epoch 15: 958 / 10000
# Epoch 16: 1028 / 10000
# Epoch 17: 958 / 10000
# Epoch 18: 974 / 10000
# Epoch 19: 1009 / 10000
# Epoch 20: 974 / 10000
# Epoch 21: 1028 / 10000
# Epoch 22: 974 / 10000
# Epoch 23: 1032 / 10000
# Epoch 24: 982 / 10000
# Epoch 25: 1135 / 10000
# Epoch 26: 1135 / 10000
# Epoch 27: 1135 / 10000
# Epoch 28: 1028 / 10000
# Epoch 29: 1009 / 10000

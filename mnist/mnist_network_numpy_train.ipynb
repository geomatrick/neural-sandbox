# %%
import mnist_loader
import mnist_network_numpy

training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/pickle.py:1590: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   stack[-1] = func(*args)

# %%
net = mnist_network_numpy.Network([784, 30, 10])
net.SGD(training_data, 30, 10, 3.0, test_data=test_data)
# Out:
# Epoch 0: 9039 / 10000
# Epoch 1: 9222 / 10000
# Epoch 2: 9290 / 10000
# Epoch 3: 9347 / 10000
# Epoch 4: 9362 / 10000
# Epoch 5: 9415 / 10000
# Epoch 6: 9451 / 10000
# Epoch 7: 9436 / 10000
# Epoch 8: 9465 / 10000
# Epoch 9: 9467 / 10000
# Epoch 10: 9468 / 10000
# Epoch 11: 9471 / 10000
# Epoch 12: 9486 / 10000
# Epoch 13: 9460 / 10000
# Epoch 14: 9463 / 10000
# Epoch 15: 9463 / 10000
# Epoch 16: 9486 / 10000
# Epoch 17: 9489 / 10000
# Epoch 18: 9452 / 10000
# Epoch 19: 9483 / 10000
# Epoch 20: 9498 / 10000
# Epoch 21: 9516 / 10000
# Epoch 22: 9478 / 10000
# Epoch 23: 9510 / 10000
# Epoch 24: 9487 / 10000
# Epoch 25: 9501 / 10000
# Epoch 26: 9503 / 10000
# Epoch 27: 9498 / 10000
# Epoch 28: 9520 / 10000
# Epoch 29: 9505 / 10000
